# %%
# %pip uninstall -y plotly cufflinks chart-studio
# Out:
# Found existing installation: plotly 6.3.0
# Uninstalling plotly-6.3.0:
#   Successfully uninstalled plotly-6.3.0
# Found existing installation: cufflinks 0.17.3
# Uninstalling cufflinks-0.17.3:
#   Successfully uninstalled cufflinks-0.17.3
# Found existing installation: chart-studio 1.1.0
# Uninstalling chart-studio-1.1.0:
#   Successfully uninstalled chart-studio-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotly==5.15.0 cufflinks==0.17.3 chart-studio==1.1.0
# Out:
# ...
#
# ...

# %%
# !pip install plotly
# !pip install cufflinks
# !pip install -U chart-studio plotly cufflinks
# Out:
# ...
#   Using cached plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# ...
# Using cached plotly-6.3.0-py3-none-any.whl (9.8 MB)
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ...

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].iplot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tips['total_bill'].iplot()
#
# File ~\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:1216, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1214 	return Figure(figure)
#    1215 else:
# -> 1216 	return iplot(figure,validate=validate,sharing=sharing,filename=filename,
# ...
